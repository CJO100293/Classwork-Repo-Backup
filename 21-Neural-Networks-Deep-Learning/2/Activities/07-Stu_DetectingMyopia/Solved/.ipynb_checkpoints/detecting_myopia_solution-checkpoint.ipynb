# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Out:
# 2023-08-22 16:24:06.702134: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Import our input dataset
myopia_df = pd.read_csv('https://static.bc-edx.com/data/dl-1-2/m21/lessons/2/myopia.csv')
myopia_df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
# Remove MYOPIC target from features data
y = myopia_df.MYOPIC.values
X = myopia_df.drop(columns="MYOPIC").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=14))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9299 - accuracy: 0.1814
# Epoch 2/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7735 - accuracy: 0.3801
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6623 - accuracy: 0.6199
# Epoch 4/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7840
# Epoch 5/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5094 - accuracy: 0.8337
# Epoch 6/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4556 - accuracy: 0.8488
# Epoch 7/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4159 - accuracy: 0.8596
# Epoch 8/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8618
# Epoch 9/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3666 - accuracy: 0.8639
# Epoch 10/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3519 - accuracy: 0.8683
# Epoch 11/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8683
# Epoch 12/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8683
# Epoch 13/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3226 - accuracy: 0.8683
# Epoch 14/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3151 - accuracy: 0.8683
# Epoch 15/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3077 - accuracy: 0.8704
# Epoch 16/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.8726
# Epoch 17/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.8726
# Epoch 18/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2877 - accuracy: 0.8747
# Epoch 19/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2812 - accuracy: 0.8769
# Epoch 20/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2756 - accuracy: 0.8790
# Epoch 21/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2695 - accuracy: 0.8812
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.8812
# Epoch 23/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2594 - accuracy: 0.8812
# Epoch 24/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2548 - accuracy: 0.8877
# Epoch 25/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2498 - accuracy: 0.8898
# Epoch 26/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2457 - accuracy: 0.8898
# Epoch 27/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2415 - accuracy: 0.8898
# Epoch 28/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.8942
# Epoch 29/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2340 - accuracy: 0.8985
# Epoch 30/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2301 - accuracy: 0.9050
# Epoch 31/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2269 - accuracy: 0.9028
# Epoch 32/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9006
# Epoch 33/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2202 - accuracy: 0.9050
# Epoch 34/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2170 - accuracy: 0.9071
# Epoch 35/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2147 - accuracy: 0.9071
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9114
# Epoch 37/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2085 - accuracy: 0.9158
# Epoch 38/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9179
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2036 - accuracy: 0.9179
# Epoch 40/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2019 - accuracy: 0.9222
# Epoch 41/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1991 - accuracy: 0.9244
# Epoch 42/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1969 - accuracy: 0.9266
# Epoch 43/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1954 - accuracy: 0.9244
# Epoch 44/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.9244
# Epoch 45/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1913 - accuracy: 0.9266
# Epoch 46/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1896 - accuracy: 0.9309
# Epoch 47/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1879 - accuracy: 0.9309
# Epoch 48/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1865 - accuracy: 0.9309
# Epoch 49/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1855 - accuracy: 0.9330
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9330
# 5/5 - 0s - loss: 0.4121 - accuracy: 0.8645 - 125ms/epoch - 25ms/step
# Loss: 0.4120822250843048, Accuracy: 0.8645161390304565
