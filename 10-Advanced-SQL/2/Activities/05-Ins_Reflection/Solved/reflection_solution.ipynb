# %%
# Import the Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///../Resources/dow.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(autoload_with=engine)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['dow']

# %%
# Assign the dow class to a variable called `Dow`
Dow = Base.classes.dow
Dow
# Out:
# sqlalchemy.ext.automap.dow

# %%
# Create a session
session = Session(engine)

# %%
rows = session.query(Dow)
for row in rows:
    print(f"{row.id} {row.quarter} {row.stock}")
# Out:
# 1 1 AA
# 2 1 AA
# 3 1 AA
# 4 1 AA
# 5 1 AA
# 6 1 AA
# 7 1 AA
# 8 1 AA
# 9 1 AA
# 10 1 AA
# 11 1 AA
# 12 1 AA
# 13 1 AXP
# 14 1 AXP
# 15 1 AXP
# 16 1 AXP
# 17 1 AXP
# 18 1 AXP
# 19 1 AXP
# 20 1 AXP
# 21 1 AXP
# 22 1 AXP
# 23 1 AXP
# 24 1 AXP
# 25 1 BA
# 26 1 BA
# 27 1 BA
# 28 1 BA
# 29 1 BA
# 30 1 BA
# 31 1 BA
# 32 1 BA
# 33 1 BA
# 34 1 BA
# 35 1 BA
# 36 1 BA
# 37 1 BAC
# 38 1 BAC
# 39 1 BAC
# 40 1 BAC
# 41 1 BAC
# 42 1 BAC
# 43 1 BAC
# 44 1 BAC
# 45 1 BAC
# 46 1 BAC
# 47 1 BAC
# 48 1 BAC
# 49 1 CAT
# 50 1 CAT
# 51 1 CAT
# 52 1 CAT
# 53 1 CAT
# 54 1 CAT
# 55 1 CAT
# 56 1 CAT
# 57 1 CAT
# 58 1 CAT
# 59 1 CAT
# 60 1 CAT
# 61 1 CSCO
# 62 1 CSCO
# 63 1 CSCO
# 64 1 CSCO
# 65 1 CSCO
# 66 1 CSCO
# 67 1 CSCO
# 68 1 CSCO
# 69 1 CSCO
# 70 1 CSCO
# 71 1 CSCO
# 72 1 CSCO
# 73 1 CVX
# 74 1 CVX
# 75 1 CVX
# 76 1 CVX
# 77 1 CVX
# 78 1 CVX
# 79 1 CVX
# 80 1 CVX
# 81 1 CVX
# 82 1 CVX
# 83 1 CVX
# 84 1 CVX
# 85 1 DD
# 86 1 DD
# 87 1 DD
# 88 1 DD
# 89 1 DD
# 90 1 DD
# 91 1 DD
# 92 1 DD
# 93 1 DD
# 94 1 DD
# 95 1 DD
# 96 1 DD
# 97 1 DIS
# 98 1 DIS
# 99 1 DIS
# 100 1 DIS
# 101 1 DIS
# 102 1 DIS
# 103 1 DIS
# 104 1 DIS
# 105 1 DIS
# 106 1 DIS
# 107 1 DIS
# 108 1 DIS
# 109 1 GE
# 110 1 GE
# 111 1 GE
# 112 1 GE
# 113 1 GE
# 114 1 GE
# 115 1 GE
# 116 1 GE
# 117 1 GE
# 118 1 GE
# 119 1 GE
# 120 1 GE
# 121 1 HD
# 122 1 HD
# 123 1 HD
# 124 1 HD
# 125 1 HD
# 126 1 HD
# 127 1 HD
# 128 1 HD
# 129 1 HD
# 130 1 HD
# 131 1 HD
# 132 1 HD
# 133 1 HPQ
# 134 1 HPQ
# 135 1 HPQ
# 136 1 HPQ
# 137 1 HPQ
# 138 1 HPQ
# 139 1 HPQ
# 140 1 HPQ
# 141 1 HPQ
# 142 1 HPQ
# 143 1 HPQ
# 144 1 HPQ
# 145 1 IBM
# 146 1 IBM
# 147 1 IBM
# 148 1 IBM
# 149 1 IBM
# 150 1 IBM
# 151 1 IBM
# 152 1 IBM
# 153 1 IBM
# 154 1 IBM
# 155 1 IBM
# 156 1 IBM
# 157 1 INTC
# 158 1 INTC
# 159 1 INTC
# 160 1 INTC
# 161 1 INTC
# 162 1 INTC
# 163 1 INTC
# 164 1 INTC
# 165 1 INTC
# 166 1 INTC
# 167 1 INTC
# 168 1 INTC
# 169 1 JNJ
# 170 1 JNJ
# 171 1 JNJ
# 172 1 JNJ
# 173 1 JNJ
# 174 1 JNJ
# 175 1 JNJ
# 176 1 JNJ
# 177 1 JNJ
# 178 1 JNJ
# 179 1 JNJ
# 180 1 JNJ
# 181 1 JPM
# 182 1 JPM
# 183 1 JPM
# 184 1 JPM
# 185 1 JPM
# 186 1 JPM
# 187 1 JPM
# 188 1 JPM
# 189 1 JPM
# 190 1 JPM
# 191 1 JPM
# 192 1 JPM
# 193 1 KRFT
# 194 1 KRFT
# 195 1 KRFT
# 196 1 KRFT
# 197 1 KRFT
# 198 1 KRFT
# 199 1 KRFT
# 200 1 KRFT
# 201 1 KRFT
# 202 1 KRFT
# 203 1 KRFT
# 204 1 KRFT
# 205 1 KO
# 206 1 KO
# 207 1 KO
# 208 1 KO
# 209 1 KO
# 210 1 KO
# 211 1 KO
# 212 1 KO
# 213 1 KO
# 214 1 KO
# 215 1 KO
# 216 1 KO
# 217 1 MCD
# 218 1 MCD
# 219 1 MCD
# 220 1 MCD
# 221 1 MCD
# 222 1 MCD
# 223 1 MCD
# 224 1 MCD
# 225 1 MCD
# 226 1 MCD
# 227 1 MCD
# 228 1 MCD
# 229 1 MMM
# 230 1 MMM
# 231 1 MMM
# 232 1 MMM
# 233 1 MMM
# 234 1 MMM
# 235 1 MMM
# 236 1 MMM
# 237 1 MMM
# 238 1 MMM
# 239 1 MMM
# 240 1 MMM
# 241 1 MRK
# 242 1 MRK
# 243 1 MRK
# 244 1 MRK
# 245 1 MRK
# 246 1 MRK
# 247 1 MRK
# 248 1 MRK
# 249 1 MRK
# 250 1 MRK
# 251 1 MRK
# 252 1 MRK
# 253 1 MSFT
# 254 1 MSFT
# 255 1 MSFT
# 256 1 MSFT
# 257 1 MSFT
# 258 1 MSFT
# 259 1 MSFT
# 260 1 MSFT
# 261 1 MSFT
# 262 1 MSFT
# 263 1 MSFT
# 264 1 MSFT
# 265 1 PFE
# 266 1 PFE
# 267 1 PFE
# 268 1 PFE
# 269 1 PFE
# 270 1 PFE
# 271 1 PFE
# 272 1 PFE
# 273 1 PFE
# 274 1 PFE
# 275 1 PFE
# 276 1 PFE
# 277 1 PG
# 278 1 PG
# 279 1 PG
# 280 1 PG
# 281 1 PG
# 282 1 PG
# 283 1 PG
# 284 1 PG
# 285 1 PG
# 286 1 PG
# 287 1 PG
# 288 1 PG
# 289 1 T
# 290 1 T
# 291 1 T
# 292 1 T
# 293 1 T
# 294 1 T
# 295 1 T
# 296 1 T
# 297 1 T
# 298 1 T
# 299 1 T
# 300 1 T
# 301 1 TRV
# 302 1 TRV
# 303 1 TRV
# 304 1 TRV
# 305 1 TRV
# 306 1 TRV
# 307 1 TRV
# 308 1 TRV
# 309 1 TRV
# 310 1 TRV
# 311 1 TRV
# 312 1 TRV
# 313 1 UTX
# 314 1 UTX
# 315 1 UTX
# 316 1 UTX
# 317 1 UTX
# 318 1 UTX
# 319 1 UTX
# 320 1 UTX
# 321 1 UTX
# 322 1 UTX
# 323 1 UTX
# 324 1 UTX
# 325 1 VZ
# 326 1 VZ
# 327 1 VZ
# 328 1 VZ
# 329 1 VZ
# 330 1 VZ
# 331 1 VZ
# 332 1 VZ
# 333 1 VZ
# 334 1 VZ
# 335 1 VZ
# 336 1 VZ
# 337 1 WMT
# 338 1 WMT
# 339 1 WMT
# 340 1 WMT
# 341 1 WMT
# 342 1 WMT
# 343 1 WMT
# 344 1 WMT
# 345 1 WMT
# 346 1 WMT
# 347 1 WMT
# 348 1 WMT
# 349 1 XOM
# 350 1 XOM
# 351 1 XOM
# 352 1 XOM
# 353 1 XOM
# 354 1 XOM
# 355 1 XOM
# 356 1 XOM
# 357 1 XOM
# 358 1 XOM
# 359 1 XOM
# 360 1 XOM
# 361 2 AA
# 362 2 AA
# 363 2 AA
# 364 2 AA
# 365 2 AA
# 366 2 AA
# 367 2 AA
# 368 2 AA
# 369 2 AA
# 370 2 AA
# 371 2 AA
# 372 2 AA
# 373 2 AA
# 374 2 AXP
# 375 2 AXP
# 376 2 AXP
# 377 2 AXP
# 378 2 AXP
# 379 2 AXP
# 380 2 AXP
# 381 2 AXP
# 382 2 AXP
# 383 2 AXP
# 384 2 AXP
# 385 2 AXP
# 386 2 AXP
# 387 2 BA
# 388 2 BA
# 389 2 BA
# 390 2 BA
# 391 2 BA
# 392 2 BA
# 393 2 BA
# 394 2 BA
# 395 2 BA
# 396 2 BA
# 397 2 BA
# 398 2 BA
# 399 2 BA
# 400 2 BAC
# 401 2 BAC
# 402 2 BAC
# 403 2 BAC
# 404 2 BAC
# 405 2 BAC
# 406 2 BAC
# 407 2 BAC
# 408 2 BAC
# 409 2 BAC
# 410 2 BAC
# 411 2 BAC
# 412 2 BAC
# 413 2 CAT
# 414 2 CAT
# 415 2 CAT
# 416 2 CAT
# 417 2 CAT
# 418 2 CAT
# 419 2 CAT
# 420 2 CAT
# 421 2 CAT
# 422 2 CAT
# 423 2 CAT
# 424 2 CAT
# 425 2 CAT
# 426 2 CSCO
# 427 2 CSCO
# 428 2 CSCO
# 429 2 CSCO
# 430 2 CSCO
# 431 2 CSCO
# 432 2 CSCO
# 433 2 CSCO
# 434 2 CSCO
# 435 2 CSCO
# 436 2 CSCO
# 437 2 CSCO
# 438 2 CSCO
# 439 2 CVX
# 440 2 CVX
# 441 2 CVX
# 442 2 CVX
# 443 2 CVX
# 444 2 CVX
# 445 2 CVX
# 446 2 CVX
# 447 2 CVX
# 448 2 CVX
# 449 2 CVX
# 450 2 CVX
# 451 2 CVX
# 452 2 DD
# 453 2 DD
# 454 2 DD
# 455 2 DD
# 456 2 DD
# 457 2 DD
# 458 2 DD
# 459 2 DD
# 460 2 DD
# 461 2 DD
# 462 2 DD
# 463 2 DD
# 464 2 DD
# 465 2 DIS
# 466 2 DIS
# 467 2 DIS
# 468 2 DIS
# 469 2 DIS
# 470 2 DIS
# 471 2 DIS
# 472 2 DIS
# 473 2 DIS
# 474 2 DIS
# 475 2 DIS
# 476 2 DIS
# 477 2 DIS
# 478 2 GE
# 479 2 GE
# 480 2 GE
# 481 2 GE
# 482 2 GE
# 483 2 GE
# 484 2 GE
# 485 2 GE
# 486 2 GE
# 487 2 GE
# 488 2 GE
# 489 2 GE
# 490 2 GE
# 491 2 HD
# 492 2 HD
# 493 2 HD
# 494 2 HD
# 495 2 HD
# 496 2 HD
# 497 2 HD
# 498 2 HD
# 499 2 HD
# 500 2 HD
# 501 2 HD
# 502 2 HD
# 503 2 HD
# 504 2 HPQ
# 505 2 HPQ
# 506 2 HPQ
# 507 2 HPQ
# 508 2 HPQ
# 509 2 HPQ
# 510 2 HPQ
# 511 2 HPQ
# 512 2 HPQ
# 513 2 HPQ
# 514 2 HPQ
# 515 2 HPQ
# 516 2 HPQ
# 517 2 IBM
# 518 2 IBM
# 519 2 IBM
# 520 2 IBM
# 521 2 IBM
# 522 2 IBM
# 523 2 IBM
# 524 2 IBM
# 525 2 IBM
# 526 2 IBM
# 527 2 IBM
# 528 2 IBM
# 529 2 IBM
# 530 2 INTC
# 531 2 INTC
# 532 2 INTC
# 533 2 INTC
# 534 2 INTC
# 535 2 INTC
# 536 2 INTC
# 537 2 INTC
# 538 2 INTC
# 539 2 INTC
# 540 2 INTC
# 541 2 INTC
# 542 2 INTC
# 543 2 JNJ
# 544 2 JNJ
# 545 2 JNJ
# 546 2 JNJ
# 547 2 JNJ
# 548 2 JNJ
# 549 2 JNJ
# 550 2 JNJ
# 551 2 JNJ
# 552 2 JNJ
# 553 2 JNJ
# 554 2 JNJ
# 555 2 JNJ
# 556 2 JPM
# 557 2 JPM
# 558 2 JPM
# 559 2 JPM
# 560 2 JPM
# 561 2 JPM
# 562 2 JPM
# 563 2 JPM
# 564 2 JPM
# 565 2 JPM
# 566 2 JPM
# 567 2 JPM
# 568 2 JPM
# 569 2 KRFT
# 570 2 KRFT
# 571 2 KRFT
# 572 2 KRFT
# 573 2 KRFT
# 574 2 KRFT
# 575 2 KRFT
# 576 2 KRFT
# 577 2 KRFT
# 578 2 KRFT
# 579 2 KRFT
# 580 2 KRFT
# 581 2 KRFT
# 582 2 KO
# 583 2 KO
# 584 2 KO
# 585 2 KO
# 586 2 KO
# 587 2 KO
# 588 2 KO
# 589 2 KO
# 590 2 KO
# 591 2 KO
# 592 2 KO
# 593 2 KO
# 594 2 KO
# 595 2 MCD
# 596 2 MCD
# 597 2 MCD
# 598 2 MCD
# 599 2 MCD
# 600 2 MCD
# 601 2 MCD
# 602 2 MCD
# 603 2 MCD
# 604 2 MCD
# 605 2 MCD
# 606 2 MCD
# 607 2 MCD
# 608 2 MMM
# 609 2 MMM
# 610 2 MMM
# 611 2 MMM
# 612 2 MMM
# 613 2 MMM
# 614 2 MMM
# 615 2 MMM
# 616 2 MMM
# 617 2 MMM
# 618 2 MMM
# 619 2 MMM
# 620 2 MMM
# 621 2 MRK
# 622 2 MRK
# 623 2 MRK
# 624 2 MRK
# 625 2 MRK
# 626 2 MRK
# 627 2 MRK
# 628 2 MRK
# 629 2 MRK
# 630 2 MRK
# 631 2 MRK
# 632 2 MRK
# 633 2 MRK
# 634 2 MSFT
# 635 2 MSFT
# 636 2 MSFT
# 637 2 MSFT
# 638 2 MSFT
# 639 2 MSFT
# 640 2 MSFT
# 641 2 MSFT
# 642 2 MSFT
# 643 2 MSFT
# 644 2 MSFT
# 645 2 MSFT
# 646 2 MSFT
# 647 2 PFE
# 648 2 PFE
# 649 2 PFE
# 650 2 PFE
# 651 2 PFE
# 652 2 PFE
# 653 2 PFE
# 654 2 PFE
# 655 2 PFE
# 656 2 PFE
# 657 2 PFE
# 658 2 PFE
# 659 2 PFE
# 660 2 PG
# 661 2 PG
# 662 2 PG
# 663 2 PG
# 664 2 PG
# 665 2 PG
# 666 2 PG
# 667 2 PG
# 668 2 PG
# 669 2 PG
# 670 2 PG
# 671 2 PG
# 672 2 PG
# 673 2 T
# 674 2 T
# 675 2 T
# 676 2 T
# 677 2 T
# 678 2 T
# 679 2 T
# 680 2 T
# 681 2 T
# 682 2 T
# 683 2 T
# 684 2 T
# 685 2 T
# 686 2 TRV
# 687 2 TRV
# 688 2 TRV
# 689 2 TRV
# 690 2 TRV
# 691 2 TRV
# 692 2 TRV
# 693 2 TRV
# 694 2 TRV
# 695 2 TRV
# 696 2 TRV
# 697 2 TRV
# 698 2 TRV
# 699 2 UTX
# 700 2 UTX
# 701 2 UTX
# 702 2 UTX
# 703 2 UTX
# 704 2 UTX
# 705 2 UTX
# 706 2 UTX
# 707 2 UTX
# 708 2 UTX
# 709 2 UTX
# 710 2 UTX
# 711 2 UTX
# 712 2 VZ
# 713 2 VZ
# 714 2 VZ
# 715 2 VZ
# 716 2 VZ
# 717 2 VZ
# 718 2 VZ
# 719 2 VZ
# 720 2 VZ
# 721 2 VZ
# 722 2 VZ
# 723 2 VZ
# 724 2 VZ
# 725 2 WMT
# 726 2 WMT
# 727 2 WMT
# 728 2 WMT
# 729 2 WMT
# 730 2 WMT
# 731 2 WMT
# 732 2 WMT
# 733 2 WMT
# 734 2 WMT
# 735 2 WMT
# 736 2 WMT
# 737 2 WMT
# 738 2 XOM
# 739 2 XOM
# 740 2 XOM
# 741 2 XOM
# 742 2 XOM
# 743 2 XOM
# 744 2 XOM
# 745 2 XOM
# 746 2 XOM
# 747 2 XOM
# 748 2 XOM
# 749 2 XOM
# 750 2 XOM

# %%
# Display the row's columns and data in dictionary format
first_row = session.query(Dow).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x7fe450818310>,
#  'date': '2011-01-07',
#  'id': 1,
#  'high_price': 16.72,
#  'close_price': 16.42,
#  'volume': 239655616,
#  'quarter': 1,
#  'stock': 'AA',
#  'open_price': 15.82,
#  'low_price': 15.78,
#  'percent_change': None}

# %%
# Use the session to query Dow table and display the first 5 trade volumes
for row in session.query(Dow.stock, Dow.volume).limit(15).all():
    print(row)
# Out:
# ('AA', 239655616)
# ('AA', 242963398)
# ('AA', 138428495)
# ('AA', 151379173)
# ('AA', 154387761)
# ('AA', 114691279)
# ('AA', 80023895)
# ('AA', 132981863)
# ('AA', 109493077)
# ('AA', 114332562)
# ('AA', 130374108)
# ('AA', 95550392)
# ('AXP', 45102042)
# ('AXP', 25913713)
# ('AXP', 38824728)
